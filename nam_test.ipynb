# %%
import pandas as pd
from tj_hyd_nam import TJHydNAM, NAMColNames, NAMConfig

NAM = TJHydNAM(
    pd.read_csv('Test.csv'),
    NAMColNames(
        date='Date',
        temperature='Temp',
        precipitation='P',
        evapotranspiration='E',
        discharge='Q'
    ),
    NAMConfig(
        area=58.8,
        start_date=None,
        end_date=None,
        interval=24.0,
        spin_off=0.0,
        umax=0.97,
        lmax=721.56,
        cqof=0.18,
        ckif=495.91,
        ck12=25.16,
        tof=0.97,
        tif=0.11,
        tg=0.19,
        ckbf=1121.74,
        csnow=2.31,
        snowtemp=3.51,
    )
)
print(NAM)
NAM.optimize()
NAM.show()
NAM.re_config_by_props(
    start_date=pd.to_datetime('09/10/2016', dayfirst=True, utc=True),
    end_date=pd.to_datetime('20/10/2016', dayfirst=True, utc=True)
)
NAM.show()
# Out:
# TJ_HYD_NAM 🍃 🌧 ☔ 💦
# FROM: 2016-10-09 00:00:00+00:00
# TO: 2018-09-30 00:00:00+00:00
# NAMConfig(area=58.8, start_date=None, end_date=None, flow_rate=0.6805555555555555, interval=24.0, spin_off=0.0, umax=0.97, lmax=721.56, cqof=0.18, ckif=495.91, ck12=25.16, tof=0.97, tif=0.11, tg=0.19, ckbf=1121.74, csnow=2.31, snowtemp=3.51)
# NAMStatistic(nse=-0.17835445482281131, rmse=1.7864602332317054, fbias=75.23828249740461)

# %%
NAM.show()

# %%
NAM.re_config_by_props(
    start_date=pd.to_datetime('09/10/2016', dayfirst=True, utc=True),
    end_date=pd.to_datetime('20/10/2016', dayfirst=True, utc=True)
)
print(NAM)
# Out:
# TJ_HYD_NAM 🍃 🌧 ☔ 💦
# FROM: 2016-10-09 00:00:00+00:00
# TO: 2016-10-20 00:00:00+00:00
# NAMConfig(area=58.8, start_date=Timestamp('2016-10-09 00:00:00+0000', tz='UTC'), end_date=Timestamp('2016-10-20 00:00:00+0000', tz='UTC'), flow_rate=0.6805555555555555, interval=24.0, spin_off=0.0, umax=10.0, lmax=100.0, cqof=0.1, ckif=200.0, ck12=10.0, tof=0.0, tif=0.0, tg=0.0, ckbf=1000.0, csnow=0.0, snowtemp=0.0)
# NAMStatistic(nse=-93.90733942666992, rmse=0.24765646546511538, fbias=79.54516156099962)
